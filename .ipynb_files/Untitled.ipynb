# %%
import pandas as pd

# %%
df_santa_cruz_2025 = pd.read_csv('data/clean/Santa_Cruz/Santa_Cruz_Results_2025.csv')

# %%
df_santa_cruz_2025.head(10)
# Out:
#       athlete_name  athlete_bib  gender age_group        country  \
# 0     Sam Appleton           50     1.0      MPRO      Australia
# 1     Trevor Foley           52     1.0      MPRO  United States
# 2       Ben Kanute           53     1.0      MPRO  United States
# 3       Luke Jones           74     1.0      MPRO  United States
# 4         Ari Klau           55     1.0      MPRO  United States
# 5  Jackson Laundry           51     1.0      MPRO         Canada
# 6     Andy Krueger           61     1.0      MPRO  United States
# 7    Miguel Mattox           60     1.0      MPRO  United States
# 8   Justin Metzler           58     1.0      MPRO  United States
# 9      Connor Ford           56     1.0      MPRO  United States
#
#   swim_time_formatted  swim_time_seconds  t1_time  t1_time_seconds  \
# 0             0:22:45               1365  0:03:10              190
# 1             0:24:12               1452  0:03:23              203
# ...
